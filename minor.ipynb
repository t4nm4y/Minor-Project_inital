# %%
import pandas as pd
df=pd.read_csv("Sales_August_2019.csv")

# deleting the columns
df.pop('Price Each')
df.pop('Purchase Address')

#storing the changes in a new csv file
df.to_csv('Edit_Sales_August_2019.csv')

# %%
df=pd.read_csv("Edit_Sales_August_2019.csv")
df
# Out:
#        Unnamed: 0 Order ID                     Product Quantity Ordered  \
# 0               0   236670            Wired Headphones                2
# 1               1   236671  Bose SoundSport Headphones                1
# 2               2   236672                      iPhone                1
# 3               3   236673       AA Batteries (4-pack)                2
# 4               4   236674       AA Batteries (4-pack)                2
# ...           ...      ...                         ...              ...
# 12006       12006   248146  Bose SoundSport Headphones                1
# 12007       12007   248147      AAA Batteries (4-pack)                3
# 12008       12008   248148       AA Batteries (4-pack)                1
# 12009       12009   248149        USB-C Charging Cable                1
# 12010       12010   248150       AA Batteries (4-pack)                1
#
#            Order Date
# 0      08/31/19 22:21
# 1      08/15/19 15:11
# 2      08/06/19 14:40
# 3      08/29/19 20:59
# 4      08/15/19 19:53
# ...               ...
# 12006  08/29/19 22:19
# 12007  08/31/19 16:26
# 12008  08/02/19 07:25
# 12009  08/08/19 12:10
# 12010  08/16/19 08:13
#
# [12011 rows x 5 columns]
